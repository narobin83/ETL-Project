# %%
import pandas as pd
file_name = "oscars.csv"

# %%
df.head()
# Out:
#    year_film      Category  gender           name   Race              film  \
# 0       1927    Best Actor    Male  Emil Jannings  White  The Last Command
# 1       1927  Best Actress  Female   Janet Gaynor  White        7th Heaven
# 2       1928    Best Actor    Male  Warner Baxter  White    In Old Arizona
# 3       1928  Best Actress  Female  Mary Pickford  White          Coquette
# 4       1929    Best Actor    Male  George Arliss  White          Disraeli
#
#    winner
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True

# %%
#drop colum 2 
df.drop(columns=['Race', 'gender', 'name','film'])
# Out:
#        year_film                          Category  winner
# 0           1927                        Best Actor    True
# 1           1927                      Best Actress    True
# 2           1928                        Best Actor    True
# 3           1928                      Best Actress    True
# 4           1929                        Best Actor    True
# ...          ...                               ...     ...
# 10391       2019  JEAN HERSHOLT HUMANITARIAN AWARD    True
# 10392       2019                    HONORARY AWARD    True
# 10393       2019                    HONORARY AWARD    True
# 10394       2019                    HONORARY AWARD    True
# 10395       1992                    COSTUME DESIGN   False
#
# [10396 rows x 3 columns]

# %%
s = pd.Series(['lower', 'CAPITALS', 'this is a sentence', 'SwApCaSe'])
