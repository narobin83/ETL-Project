# %%
import pandas as pd
from sqlalchemy import create_engine
file_name = "oscars.csv"
df = pd.read_csv("oscars.csv")
df
# Out:
#        year_film  year_ceremony  ceremony                          Category  \
# 0           1927           1928         1                        Best Actor
# 1           1927           1928         1                      Best Actress
# 2           1928           1929         2                        Best Actor
# 3           1928           1929         2                      Best Actress
# 4           1929           1930         3                        Best Actor
# ...          ...            ...       ...                               ...
# 10391       2019           2020        92  JEAN HERSHOLT HUMANITARIAN AWARD
# 10392       2019           2020        92                    HONORARY AWARD
# 10393       2019           2020        92                    HONORARY AWARD
# 10394       2019           2020        92                    HONORARY AWARD
# 10395       1992           1993        65                    COSTUME DESIGN
#
# ...

# %%
#drop colum 2 
new_df = df.drop(columns=['year_ceremony','ceremony', 'Race', 'gender', 'name'])
new_df
# Out:
#        year_film                          Category              film  winner
# 0           1927                        Best Actor  The Last Command    True
# 1           1927                      Best Actress        7th Heaven    True
# 2           1928                        Best Actor    In Old Arizona    True
# 3           1928                      Best Actress          Coquette    True
# 4           1929                        Best Actor          Disraeli    True
# ...          ...                               ...               ...     ...
# 10391       2019  JEAN HERSHOLT HUMANITARIAN AWARD               NaN    True
# 10392       2019                    HONORARY AWARD               NaN    True
# 10393       2019                    HONORARY AWARD               NaN    True
# 10394       2019                    HONORARY AWARD               NaN    True
# 10395       1992                    COSTUME DESIGN          Malcom X   False
#
# [10396 rows x 4 columns]

# %%
new_df = new_df.rename(columns={"film":"title","year_film":"year","Category":"category"})
new_df
# Out:
#        year                          category             title  winner
# 0      1927                        Best Actor  The Last Command    True
# 1      1927                      Best Actress        7th Heaven    True
# 2      1928                        Best Actor    In Old Arizona    True
# 3      1928                      Best Actress          Coquette    True
# 4      1929                        Best Actor          Disraeli    True
# ...     ...                               ...               ...     ...
# 10391  2019  JEAN HERSHOLT HUMANITARIAN AWARD               NaN    True
# 10392  2019                    HONORARY AWARD               NaN    True
# 10393  2019                    HONORARY AWARD               NaN    True
# 10394  2019                    HONORARY AWARD               NaN    True
# 10395  1992                    COSTUME DESIGN          Malcom X   False
#
# [10396 rows x 4 columns]

# %%
# lowercase Category column 
new_df['category'] = new_df['category'].str.capitalize()

new_df['category'].unique()
# Out:
# array(['Best actor', 'Best actress', 'Best actor in supporting role',
#        'Actress in a supporting role', 'Production design',
#        'Cinematography', 'Directing (comedy picture)',
#        'Directing (dramatic picture)', 'Engineering effects',
#        'Best picture', 'Unique and artistic picture',
#        'Writing (adapted screenplay)', 'Writing (original story)',
#        'Writing (title writing)', 'Special award', 'Directing',
#        'Sound recording', 'Short subject (cartoon)',
#        'Short subject (comedy)', 'Short subject (novelty)',
#        'Assistant director', 'Film editing', 'Music (scoring)',
#        'Music (song)', 'Dance direction', 'Short subject (color)',
#        'Short subject (one-reel)', 'Short subject (two-reel)',
#        'Irving g. thalberg memorial award', 'Music (original score)',
#        'Special effects', 'Art direction (black-and-white)',
#        'Art direction (color)', 'Writing (original screenplay)',
# ...

# %%
new_df = new_df.dropna(subset=["title"],how="any")

# %%
new_df = new_df.drop_duplicates(subset=["title"],keep="first")

# %%
# Database Setup
username = 'postgres'
password = 'postgres'

engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/movies_ETL')
rds_connection_string ="postgres:postgres@localhost:5432/movies_ETL"

# %%
new_df.to_sql(name="oscars", con=engine, if_exists= "append", index=False)
