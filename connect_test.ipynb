# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "rotten_tomatoes_top_movies.csv"
rotten_movies_df = pd.read_csv(csv_file)
rotten_movies_df.head()
# Out:
#    Unnamed: 0                              title  year  \
# 0           0                      Black Panther  2018
# 1           1                  Avengers: Endgame  2019
# 2           2     Mission: Impossible -- Fallout  2018
# 3           3                 Mad Max: Fury Road  2015
# 4           4  Spider-Man: Into the Spider-Verse  2018
#
#                                             synopsis  critic_score  \
# 0  After the death of his father, T'Challa return...            96
# 1  Adrift in space with no food or water, Tony St...            94
# 2  Ethan Hunt and the IMF team join forces with C...            97
# 3  Years after the collapse of civilization, the ...            97
# 4  Bitten by a radioactive spider in the subway, ...            97
#
#    people_score                                          consensus  \
# 0          79.0  Black Panther elevates superhero cinema to thr...
# 1          90.0  Exciting, entertaining, and emotionally impact...
# ...

# %%
new_rotten_movies_df = rotten_movies_df[['title', 'critic_score', 'people_score', 'total_reviews', 'rating']].copy()
new_rotten_movies_df
# Out:
#                                   title  critic_score  people_score  \
# 0                         Black Panther            96          79.0
# 1                     Avengers: Endgame            94          90.0
# 2        Mission: Impossible -- Fallout            97          88.0
# 3                    Mad Max: Fury Road            97          86.0
# 4     Spider-Man: Into the Spider-Verse            97          93.0
# ...                                 ...           ...           ...
# 1605                             Priest            15          46.0
# 1606                     September Dawn            16          49.0
# 1607                   American Outlaws            14          68.0
# 1608                          Jonah Hex            12          20.0
# 1609                      Texas Rangers             2          29.0
#
#       total_reviews                                             rating
# 0               519  PG-13 (Sequences of Action Violence|A Brief Ru...
# ...

# %%
rds_connection_string = "postgres:postgres@localhost:5432/movies_ETL"

# %%
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['oscars', 'rotten_tomatoes_data']

# %%
new_rotten_movies_df.to_sql(name="rotten_tomatoes_data",con=engine, if_exists="append", index=False)
# Out:
# ---------------------------------------------------------------------------
# NotNullViolation                          Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1257                     self.dialect.do_executemany(
# -> 1258                         cursor, statement, parameters, context
#    1259                     )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# NotNullViolation: null value in column "rating" of relation "rotten_tomatoes_data" violates not-null constraint
# DETAIL:  Failing row contains (King Kong, 98, 86, 65, null).
#
#
# ...
