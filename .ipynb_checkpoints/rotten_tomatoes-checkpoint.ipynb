# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "rotten_tomatoes_top_movies.csv"
rotten_movies_df = pd.read_csv(csv_file)
rotten_movies_df.head()
# Out:
#    Unnamed: 0                              title  year  \
# 0           0                      Black Panther  2018
# 1           1                  Avengers: Endgame  2019
# 2           2     Mission: Impossible -- Fallout  2018
# 3           3                 Mad Max: Fury Road  2015
# 4           4  Spider-Man: Into the Spider-Verse  2018
#
#                                             synopsis  critic_score  \
# 0  After the death of his father, T'Challa return...            96
# 1  Adrift in space with no food or water, Tony St...            94
# 2  Ethan Hunt and the IMF team join forces with C...            97
# 3  Years after the collapse of civilization, the ...            97
# 4  Bitten by a radioactive spider in the subway, ...            97
#
#    people_score                                          consensus  \
# 0          79.0  Black Panther elevates superhero cinema to thr...
# 1          90.0  Exciting, entertaining, and emotionally impact...
# ...

# %%
duplicate_title = rotten_movies_df.loc[rotten_movies_df.duplicated(subset=['title',]),'title'].unique()
duplicate_title
# Out:
# array(['Spider-Man: Into the Spider-Verse', 'Coco', 'Incredibles 2',
#        'Zootopia', 'Up', 'The LEGO Movie', 'Moana', 'Isle of Dogs',
#        'Kubo and the Two Strings', 'WALL-E', 'The LEGO Batman Movie',
#        'Chicken Run', 'Onward', 'The Lion King',
#        'Who Framed Roger Rabbit', 'Seven Samurai', 'Metropolis',
#        'My Life as a Zucchini', 'Only Yesterday', 'Stalker', 'Ran',
#        'A Fistful of Dollars', 'Grave of the Fireflies',
#        'Crouching Tiger, Hidden Dragon', 'Aguirre: The Wrath of God',
#        'Waltz With Bashir', 'Ernest & Célestine',
#        'The Cabinet of Dr. Caligari', 'Grand Illusion',
#        'Snow White and the Seven Dwarfs', 'The Adventures of Robin Hood',
#        'King Kong', 'Nosferatu', 'The 400 Blows',
#        'The Treasure of the Sierra Madre', 'The 39 Steps',
#        'Lawrence of Arabia', 'Rashomon', 'Potemkin', 'Stagecoach',
#        'Goldfinger', 'The Passion of Joan of Arc', 'The African Queen',
# ...

# %%
clean_df = rotten_movies_df[rotten_movies_df['title'].isin(duplicate_title)==False]
clean_df
# Out:
#       Unnamed: 0                               title  year  \
# 34            34    Mission: Impossible Rogue Nation  2015
# 57            57  John Wick: Chapter 3 -- Parabellum  2019
# 75            75            The Peanut Butter Falcon  2019
# 94            94                           Apollo 13  1995
# 97            97                 Catch Me if You Can  2002
# ...          ...                                 ...   ...
# 1605        1605                              Priest  2011
# 1606        1606                      September Dawn  2006
# 1607        1607                    American Outlaws  2001
# 1608        1608                           Jonah Hex  2010
# 1609        1609                       Texas Rangers  2001
#
#                                                synopsis  critic_score  \
# 34    With the IMF now disbanded and Ethan Hunt (Tom...            94
# 57    After gunning down a member of the High Table ...            89
# ...

# %%
new_rotten_movies_df = clean_df[['title', 'critic_score', 'people_score', 'total_reviews', 'rating']].copy()
new_rotten_movies_df
# Out:
#                                    title  critic_score  people_score  \
# 34      Mission: Impossible Rogue Nation            94          87.0
# 57    John Wick: Chapter 3 -- Parabellum            89          86.0
# 75              The Peanut Butter Falcon            94          96.0
# 94                             Apollo 13            96          87.0
# 97                   Catch Me if You Can            96          89.0
# ...                                  ...           ...           ...
# 1605                              Priest            15          46.0
# 1606                      September Dawn            16          49.0
# 1607                    American Outlaws            14          68.0
# 1608                           Jonah Hex            12          20.0
# 1609                       Texas Rangers             2          29.0
#
#       total_reviews                                             rating
# ...
